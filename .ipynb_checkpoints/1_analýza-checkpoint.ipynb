# %%
import re
from datetime import datetime
import pandas as pd
import json
from pandas.io.json import json_normalize
import matplotlib
import matplotlib.pyplot as plt

# %%
with open("clanky.json", "r", encoding="utf-8") as f:
    tab = json.load(f)
tab = pd.json_normalize(tab)
tab = pd.DataFrame.from_dict(tab)

# %%
def cleanerurl(url):
    url_separators = ["?utm_","?fbclid","?ref"]
    for separator in url_separators:
        if separator in url:
            url = url.split(separator)[0]
    return(url)

# %%
tab["url"] = tab["url"].apply(lambda x: cleanerurl(x))

# %%
def domena(url):
    url = url.split("/")[2]
    url = url.split(".")[-2]
    return(url)

# %%
tab["domena"] = tab["url"].apply(lambda x: domena(x))

# %%
with open('clanky_procistene.json', 'w+', encoding='utf-8') as file:
    tab[["url","titulek","datum"]].to_json(file, date_format='iso', orient="records", indent=4, force_ascii=False)

# %%
tab
# Out:
#                                                     url  \
# 0     https://zpravy.aktualne.cz/zahranici/cinsti-st...
# 1     http://www.bbc.co.uk/programmes/p04b1g3c/episo...
# 2     http://www.czechcrunch.cz/2017/01/je-izrael-op...
# 3     http://rodneybrooks.com/unexpected-consequence...
# 4     http://archiv.ihned.cz/c1-65583860-rene-levins...
# ...                                                 ...
# 2517  https://astralcodexten.substack.com/p/book-rev...
# 2518  https://astralcodexten.substack.com/p/book-rev...
# 2519  https://blog.eladgil.com/p/ai-revolution-trans...
# 2520  https://zpravy.aktualne.cz/domaci/cesko-spolec...
# 2521  https://boudinot.medium.com/things-to-do-with-...
#
#                                                 titulek       datum  \
# 0     Čínští studenti si můžou půjčit ve školní "ban...  2017-01-31
# 1                50 Things That Made the Modern Economy  2017-01-31
# 2               Je Izrael opravdu druhé Silicon Valley?  2017-01-31
# 3     Unexpected Consequences of Self Driving Cars –...  2017-01-31
# 4     Ví, jak porazit Zemana. Dramatik a matematik R...  2017-01-31
# ...                                                 ...         ...
# 2517               Book Review: The Man From The Future  2022-12-01
# 2518                Book Review: What We Owe The Future  2022-12-01
# 2519  AI Revolution - Transformers and Large Languag...  2022-12-01
# 2520                                     Česko společně  2022-12-01
# 2521       Things to Do with an Apocalyptic Imagination  2022-12-01
#
#                                               autorstvo  \
# 0                                               [Zdroj]
# 1                                                    []
# 2                                     [Dalibor Pulkert]
# 3                                                    []
# 4     [Vladimír Ševela, K Účtu Služse Nepodařilo Při...
# ...                                                 ...
# 2517                                  [Scott Alexander]
# 2518                     [Scott Alexander, Jack Handey]
# 2519                                         [Elad Gil]
# 2520                                            [Zdroj]
# 2521                                    [Ryan Boudinot]
#
#                                                keywords        domena  \
# 0                                                    []      aktualne
# 1                                                    []            co
# 2                                                    []   czechcrunch
# 3     [brooks, driving, autonomous, level, self, dri...  rodneybrooks
# 4                                                    []         ihned
# ...                                                 ...           ...
# 2517  [book, neumanns, theory, neumann, man, hungary...      substack
# 2518  [book, happiness, child, think, world, macaski...      substack
# 2519  [large, llms, learning, transformers, language...       eladgil
# 2520                                                 []      aktualne
# 2521  [apocalyptic, things, imagination, maybe, life...        medium
#
#       delka_titulku
# 0                91
# 1                38
# 2                39
# 3                60
# 4                84
# ...             ...
# 2517             36
# 2518             35
# 2519             61
# 2520             14
# 2521             44
#
# [2522 rows x 7 columns]

# %% [markdown]
# ## statistiky odkazů

# %%
tab
# Out:
#                                                     url  \
# 0     https://zpravy.aktualne.cz/zahranici/cinsti-st...
# 1     http://www.bbc.co.uk/programmes/p04b1g3c/episo...
# 2     http://www.czechcrunch.cz/2017/01/je-izrael-op...
# 3     http://rodneybrooks.com/unexpected-consequence...
# 4     http://archiv.ihned.cz/c1-65583860-rene-levins...
# ...                                                 ...
# 2517  https://astralcodexten.substack.com/p/book-rev...
# 2518  https://astralcodexten.substack.com/p/book-rev...
# 2519  https://blog.eladgil.com/p/ai-revolution-trans...
# 2520  https://zpravy.aktualne.cz/domaci/cesko-spolec...
# 2521  https://boudinot.medium.com/things-to-do-with-...
#
#                                                 titulek       datum  \
# 0     Čínští studenti si můžou půjčit ve školní "ban...  2017-01-31
# 1                50 Things That Made the Modern Economy  2017-01-31
# 2               Je Izrael opravdu druhé Silicon Valley?  2017-01-31
# 3     Unexpected Consequences of Self Driving Cars –...  2017-01-31
# 4     Ví, jak porazit Zemana. Dramatik a matematik R...  2017-01-31
# ...                                                 ...         ...
# 2517               Book Review: The Man From The Future  2022-12-01
# 2518                Book Review: What We Owe The Future  2022-12-01
# 2519  AI Revolution - Transformers and Large Languag...  2022-12-01
# 2520                                     Česko společně  2022-12-01
# 2521       Things to Do with an Apocalyptic Imagination  2022-12-01
#
#                                               autorstvo  \
# 0                                               [Zdroj]
# 1                                                    []
# 2                                     [Dalibor Pulkert]
# 3                                                    []
# 4     [Vladimír Ševela, K Účtu Služse Nepodařilo Při...
# ...                                                 ...
# 2517                                  [Scott Alexander]
# 2518                     [Scott Alexander, Jack Handey]
# 2519                                         [Elad Gil]
# 2520                                            [Zdroj]
# 2521                                    [Ryan Boudinot]
#
#                                                keywords        domena
# 0                                                    []      aktualne
# 1                                                    []            co
# 2                                                    []   czechcrunch
# 3     [brooks, driving, autonomous, level, self, dri...  rodneybrooks
# 4                                                    []         ihned
# ...                                                 ...           ...
# 2517  [book, neumanns, theory, neumann, man, hungary...      substack
# 2518  [book, happiness, child, think, world, macaski...      substack
# 2519  [large, llms, learning, transformers, language...       eladgil
# 2520                                                 []      aktualne
# 2521  [apocalyptic, things, imagination, maybe, life...        medium
#
# [2522 rows x 6 columns]

# %%
urls_unikatni = tab["url"].drop_duplicates().to_list()

# %%
with open("odkazy.txt", "w+", encoding="utf-8") as odkazy:
        odkazy.write(str(urls_unikatni))

# %%
len(urls_unikatni)
# Out:
# 2449

# %%
tab.groupby("url")["datum"].nunique().nlargest(20)
# Out:
# url
# https://finmag.penize.cz/predplatne                                                                     8
# http://podplayer.net/                                                                                   4
# https://docs.google.com/spreadsheets/d/1LwIL_GU6FKMAaXcNAXzVo4SoCD17c2jx-9D1Pxn01YA/edit?usp=sharing    4
# https://en.wikipedia.org/wiki/Disappearance_of_Gary_Mathias                                             3
# https://fallofcivilizationspodcast.com/                                                                 3
# https://finmag.penize.cz/predplatne/vanoce                                                              3
# https://www.online.muni.cz/tema/11014-jsou-stastni-ale-nesnasenlivi-sociologove-skladaji-obraz-cechu    3
# http://finmag.penize.cz/casopis-finmag                                                                  2
# http://finmag.penize.cz/ekonomika/326051-zivot-na-vsi-luxus-na-ktery-vam-prispivaji-druzi               2
# http://finmag.penize.cz/kaleidoskop/327905-proc-se-tolik-bojime-uprchliku                               2
# http://www.ohlasy.info/clanky/2018/08/rozhovor-minx.html                                                2
# https://en.wikipedia.org/wiki/Dyatlov_Pass_incident                                                     2
# https://finmag.penize.cz/investice/336440-proc-je-nakup-vlastniho-domu-fakt-mizerna-investice           2
# https://finmag.penize.cz/kaleidoskop/407932-velka-drogova-kocovina                                      2
# https://finmag.penize.cz/penize/337025-martin-simacek-stat-si-vyrabi-vlastni-chude                      2
# https://finmag.penize.cz/recenze/327976-planeta-ktera-si-to-spocitala                                   2
# https://finmag.penize.cz/vanoce                                                                         2
# https://markmanson.net/love                                                                             2
# https://medium.com/s/powertrip/universal-basic-income-is-silicon-valleys-latest-scam-fd3e130b69a0       2
# https://vesmir.cz/cz/on-line-clanky/2018/05/kruta-historie-pokusu-na-zviratech.html                     2
# Name: datum, dtype: int64

# %% [markdown]
# ## statistiky domén

# %%
vsecky_urls = tab.url.to_list()

# %%
domeny = tab["domena"].to_list()

# %%
unikatni_domeny = tab["domena"].drop_duplicates().to_list()

# %%
len(unikatni_domeny)
# Out:
# 573

# %%
pocty = {}
for x in unikatni_domeny:
    pocet = domeny.count(x)
    pocty[x] = pocet
pocty = pd.DataFrame.from_dict(pocty, orient="index", columns=["počet"])

# %%
pocty.sort_values(by="počet",ascending=False).head(60)
# Out:
#                     počet
# penize                338
# a2larm                107
# irozhlas               89
# novinky                78
# aktualne               77
# denikreferendum        59
# nytimes                58
# facebook               58
# rozhlas                57
# theguardian            43
# idnes                  39
# respekt                39
# medium                 38
# youtube                33
# ihned                  28
# co                     28
# vesmir                 28
# heroine                27
# substack               27
# twitter                26
# bloomberg              26
# theatlantic            25
# slatestarcodex         24
# newyorker              21
# info                   21
# ceskatelevize          19
# wikipedia              18
# universitas            17
# voxpot                 16
# seznamzpravy           15
# wired                  15
# lidovky                14
# blogspot               14
# marginalrevolution     14
# noemamag               13
# ribbonfarm             12
# bbc                    11
# reportermagazin        11
# washingtonpost         10
# vox                    10
# soundcloud              9
# vice                    8
# investigace             8
# revueprostor            8
# mediar                  8
# sciencemag              8
# github                  8
# google                  7
# spotify                 7
# muni                    7
# nature                  7
# podcastaddict           7
# mall                    7
# currentaffairs          7
# hlidacipes              7
# foreignpolicy           7
# theverge                7
# h7o                     6
# podplayer               6
# reddit                  6

# %%
top_domeny = pocty[pocty["počet"] > 10].index.to_list()

# %%
tab.groupby("domena")["datum"].count().nlargest(10)
# Out:
# domena
# penize             338
# a2larm             107
# irozhlas            89
# novinky             78
# aktualne            77
# denikreferendum     59
# facebook            58
# nytimes             58
# rozhlas             57
# theguardian         43
# Name: datum, dtype: int64

# %%
tab.groupby(["domena","datum"])["domena"].count().nlargest(10)
# Out:
# domena  datum
# penize  2017-10-05    12
# info    2018-01-04     8
# mall    2020-03-26     7
# penize  2017-10-12     7
#         2017-09-14     6
#         2017-12-14     6
# github  2022-06-30     5
# penize  2017-08-24     5
#         2017-08-31     5
#         2017-09-06     5
# Name: domena, dtype: int64

# %% [markdown]
# ## délka titulků

# %%
tab["delka_titulku"]  = tab["titulek"].apply(lambda x: len(x))

# %%
tab_cz = tab[(tab.domena.isin(top_domeny)) & tab.url.str.contains(".cz/") & (tab["domena"] != "facebook") & (tab["domena"] != "blogspot")]

# %%
matplotlib.pyplot.hist(tab_cz["delka_titulku"], bins=35)
# Out:
# (array([12.,  2., 16., 25., 27., 29., 51., 59., 61., 50., 39., 54., 59.,
#         45., 54., 36., 58., 74., 48., 42., 45., 35., 29., 45., 37., 14.,
#         18.,  4.,  2.,  2.,  3.,  2.,  0.,  1.,  1.]),
#  array([  0.        ,   4.11428571,   8.22857143,  12.34285714,
#          16.45714286,  20.57142857,  24.68571429,  28.8       ,
#          32.91428571,  37.02857143,  41.14285714,  45.25714286,
#          49.37142857,  53.48571429,  57.6       ,  61.71428571,
#          65.82857143,  69.94285714,  74.05714286,  78.17142857,
#          82.28571429,  86.4       ,  90.51428571,  94.62857143,
#          98.74285714, 102.85714286, 106.97142857, 111.08571429,
#         115.2       , 119.31428571, 123.42857143, 127.54285714,
#         131.65714286, 135.77142857, 139.88571429, 144.        ]),
#  <BarContainer object of 35 artists>)

# %%
tab_cz.groupby("domena")["delka_titulku"].median().nlargest(50)
# Out:
# domena
# ihned              97.5
# irozhlas           95.0
# info               89.0
# rozhlas            86.0
# voxpot             83.0
# ceskatelevize      80.0
# aktualne           78.0
# lidovky            75.5
# universitas        74.0
# idnes              70.0
# seznamzpravy       69.0
# novinky            59.5
# heroine            56.0
# a2larm             55.0
# respekt            51.0
# denikreferendum    51.0
# penize             42.0
# reportermagazin    40.0
# vesmir             26.5
# Name: delka_titulku, dtype: float64

# %% [markdown]
# ## vyhledávání článků z jednotlivých webů

# %%
tab[tab.url.str.contains("h7o")][["url","titulek","datum"]].tail(60)
# Out:
#                                                     url  \
# 489   http://www.h7o.cz/ceskoslovensku-zdrhal-indian...
# 1239          http://www.h7o.cz/je-treba-zabit-prirodu/
# 1272  http://www.h7o.cz/bilej-bohatej-pane-nebudte-s...
# 1512        http://www.h7o.cz/clovek-visici-ve-vzduchu/
# 1991  http://www.h7o.cz/pochybne-navrhy-a-zmatena-pr...
# 2090                          http://www.h7o.cz/prezit/
#
#                                                 titulek       datum
# 489   V Československu zdrhal Indiana Jones před mil...  2018-02-21
# 1239                       Je třeba zabít přírodu – H7O  2019-06-06
# 1272          Bílej bohatej pane, nebuďte smutnej – H7O  2019-06-27
# 1512                     Člověk visící ve vzduchu – H7O  2019-12-12
# 1991         Pochybné návrhy a zmatená prohlášení – H7O  2020-10-08
# 2090                                       Přežít – H7O  2020-11-26
